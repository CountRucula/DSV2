# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.signal as sig

# %% [markdown]
# ### Aufgabe 1: Median und Mittelwert

# %%
y = np.array([120, 130, 125, 150, 200, 210, 215, 220, 230, 235, 240, 245, 250, 255, 260, 265, 270, 275,
              280, 285, 290, 295, 300, 305, 310, 315, 320, 325, 330, 335, 340, 345, 350, 355, 360, 365,
              370, 375, 380, 385, 390, 395, 400, 405, 410, 415, 420, 425, 430, 435, 15000], dtype=float)

print(f'mittelwert = {np.mean(y)}')
print(f'medial = {np.median(y)}')
# Out:
# mittelwert = 594.8039215686274
# medial = 315.0

# %% [markdown]
# ### Aufgabe 2: Medianfilter

# %%
y = np.array([0, 0.5878, 0.9511, 0.9511, 2.0000, 0.0000, -0.5878, -0.9511, -0.9511, -0.5878, -0.0000,
0.5878, 0.9511, 0.9511, 0.5878, 0.0000, -0.5878, -0.9511, -0.9511, 1.5000, -0.0000, 0.5878,
0.9511, 0.9511, 0.5878, 0.0000, -0.5878, -0.9511, -0.9511, -0.5878, -0.0000, 0.5878, 0.9511,
0.9511, 0.5878, 0.0000, 0.7500, -0.9511, -0.9511, -0.5878, -0.0000])

y_filt = sig.medfilt(y, 3)

plt.figure()
plt.plot(y, '-x')
plt.plot(y_filt)
plt.legend(['measured', 'median filtered'])
plt.grid(True)
